# %%
from src.image_captioner import ImageCaptioner

# %%
# CAPTIONS_PATH = '$YOUR_PATH$/flickr30k/results.csv' # path to flickr30k csv file
# VOCAB_PATH = 'vocab/vocab.joblib' # path to vocab file
CHECKPOINT_PATH = 'weights/checkpoint_30k-v2.ckpt'
image_captioner = ImageCaptioner(checkpoint_path=CHECKPOINT_PATH)

# %%
image_captioner.caption_image('/mnt/s/CV/flickr30k/flickr30k_images/675153.jpg')
# Out:
# two men in white shirts are practicing martial arts .

# %%
image_captioner.caption_image('https://media.istockphoto.com/id/488553966/photo/making-their-way-towards-fitness.webp?b=1&s=170667a&w=0&k=20&c=ADzXtCdmDy-SgUffSPuubFk-rhU4vTKewFdTWw7xrOc=')
# Out:
# a man and a woman are walking on the beach .

# %%
image_captioner.caption_image('https://hips.hearstapps.com/hmg-prod/images/golden-retriever-dog-running-on-fresh-snow-royalty-free-image-152643506-1549012155.jpg')
# Out:
# a brown dog is running through snow .

# %%
image_captioner.caption_image('https://static1.bigstockphoto.com/9/3/2/large1500/23990123.jpg')
# Out:
# a young boy and girl are swimming in a pool .

# %%
image_captioner.caption_image('https://www.nist.gov/sites/default/files/images/2019/09/12/crowdofpeople.jpg')
# Out:
# a group of people are standing in a crowd .
