# %% [markdown]
# # <center>Image captioning model inference experiment</center>
# Same as main [inference.ipynb](../inference.ipynb) but with `d_model=128` and `num_heads=4`

# %%
import os
os.chdir('..')
from src.image_captioner import ImageCaptioner
os.chdir('extra_research')

# %% [markdown]
# **Checkpoint** can be downloaded from *Google Drive* here: [<b>link</b>](https://drive.google.com/file/d/1xEGNuHPAuG85xdnM5eVtTBnPSdHAJyJo/view?usp=drive_link)
# **Vocabulary** can be downloaded from *GitHub* here: [<b>link</b>](https://github.com/ScReameer/Image-captioning/tree/main/vocab)

# %%
# CAPTIONS_PATH = '$YOUR_PATH$/flickr30k/results.csv' # Set your path to flickr30k csv file
# VOCAB_PATH = 'vocab/vocab.joblib' # Default path to vocab file
CHECKPOINT_PATH = 'weights/checkpoint_extra-v1.ckpt' # Set your checkpoint path
image_captioner = ImageCaptioner(checkpoint_path=CHECKPOINT_PATH, vocab_path='../vocab/vocab.joblib')

# %% [markdown]
# ## Examples
# Image from path

# %%
image_captioner.caption_image('/mnt/s/CV/flickr30k/flickr30k_images/675153.jpg')
# Out:
# two men in white shirts are fighting in a martial arts match .

# %% [markdown]
# Images from *URL*

# %%
image_captioner.caption_image('https://longermiles.com/images/gallery/Beach_Barefoot_Running/sporty-man-running-beach_1.jpg')
# Out:
# a man walking on the beach .

# %%
image_captioner.caption_image('https://hips.hearstapps.com/hmg-prod/images/golden-retriever-dog-running-on-fresh-snow-royalty-free-image-152643506-1549012155.jpg')
# Out:
# a dog running through the snow .

# %%
image_captioner.caption_image('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRDkQ-IIUIgnsMELV6r7gIoMf-zE2C5nar9TQ&s')
# Out:
# a woman is swimming in a swimming pool .

# %%
image_captioner.caption_image('https://static1.bigstockphoto.com/9/3/2/large1500/23990123.jpg')
# Out:
# two young boys are playing volleyball in a pool .

# %%
image_captioner.caption_image('https://img.freepik.com/premium-photo/young-man-cooking-lunch-home-handsome-man-preparing-delicious-food_764173-1204.jpg')
# Out:
# a man in a white shirt is cooking in a kitchen .

# %%
image_captioner.caption_image('https://www.hollywoodreporter.com/wp-content/uploads/2021/04/GettyImages-1301916189-copy-1617396036.jpg?w=1296')
# Out:
# a group of people are dancing in a circle .
